# %%
names_sample = [
"Aaberg"
,
"Aalst"
,
"Aara"
,
"Aaren"
,
"Aarika"
,
"Aaron"
,
"Aaronson"
,
"Ab"
,
"Aba"
,
"Abad"
,
"Abagael"
,
"Abagail"
,
"Abana"
,
"Abate"
,
"Abba"
,
"Abbate"
,
"Abbe"
,
"Abbey"
,
"Abbi"
,
"Abbie"
,
"Abbot"
,
"Abbotsen"
,
"Abbotson"]
names_sample
# Out:
# ['Aaberg',
#  'Aalst',
#  'Aara',
#  'Aaren',
#  'Aarika',
#  'Aaron',
#  'Aaronson',
#  'Ab',
#  'Aba',
#  'Abad',
#  'Abagael',
#  'Abagail',
#  'Abana',
#  'Abate',
#  'Abba',
#  'Abbate',
#  'Abbe',
#  'Abbey',
#  'Abbi',
#  'Abbie',
#  'Abbot',
#  'Abbotsen',
#  'Abbotson']

# %%
food_sample = [
        "apple",
        "apricot",
        "avocado",
        "banana",
        "bell pepper",
        "bilberry",
        "blackberry",
        "blackcurrant",
        "blood orange",
        "blueberry",
        "boysenberry",
        "breadfruit",
        "canary melon",
        "cantaloupe",
        "cherimoya",
        "cherry",
        "chili pepper",
        "clementine",
        "cloudberry",
        "coconut",
        "cranberry",
        "cucumber",
        "currant",
        "damson",
        "date",
        "dragonfruit",
        "durian",
        "eggplant",
        "elderberry",
        "feijoa",
        "fig",
        "goji berry",
        "gooseberry",
        "grape",
        "grapefruit",
        "guava",
        "honeydew",
        "huckleberry",
        "jackfruit",
        "jambul",
        "jujube",
        "kiwi fruit",
        "kumquat",
        "lemon",
        "lime",
        "loquat",
        "lychee",
        "mandarine",
        "mango",
        "mulberry",
        "nectarine",
        "nut",
        "olive",
        "orange",
        "pamelo",
        "papaya",
        "passionfruit",
        "peach",
        "pear",
        "persimmon",
        "physalis",
        "pineapple",
        "plum",
        "pomegranate",
        "pomelo",
        "purple mangosteen",
        "quince",
        "raisin",
        "rambutan",
        "raspberry",
        "redcurrant",
        "rock melon",
        "salal berry",
        "satsuma",
        "star fruit",
        "strawberry",
        "tamarillo",
        "tangerine",
        "tomato",
        "ugli fruit",
        "watermelon"
    ]
food_sample
# Out:
# ['apple',
#  'apricot',
#  'avocado',
#  'banana',
#  'bell pepper',
#  'bilberry',
#  'blackberry',
#  'blackcurrant',
#  'blood orange',
#  'blueberry',
#  'boysenberry',
#  'breadfruit',
#  'canary melon',
#  'cantaloupe',
#  'cherimoya',
#  'cherry',
#  'chili pepper',
#  'clementine',
#  'cloudberry',
#  'coconut',
#  'cranberry',
#  'cucumber',
#  'currant',
#  'damson',
#  'date',
#  'dragonfruit',
#  'durian',
#  'eggplant',
#  'elderberry',
#  'feijoa',
#  'fig',
#  'goji berry',
#  'gooseberry',
#  'grape',
#  'grapefruit',
#  'guava',
#  'honeydew',
#  'huckleberry',
#  'jackfruit',
#  'jambul',
#  'jujube',
#  'kiwi fruit',
#  'kumquat',
#  'lemon',
#  'lime',
#  'loquat',
#  'lychee',
#  'mandarine',
#  'mango',
#  'mulberry',
#  'nectarine',
#  'nut',
#  'olive',
#  'orange',
#  'pamelo',
#  'papaya',
#  'passionfruit',
#  'peach',
#  'pear',
#  'persimmon',
#  'physalis',
#  'pineapple',
#  'plum',
#  'pomegranate',
#  'pomelo',
#  'purple mangosteen',
#  'quince',
#  'raisin',
#  'rambutan',
#  'raspberry',
#  'redcurrant',
#  'rock melon',
#  'salal berry',
#  'satsuma',
#  'star fruit',
#  'strawberry',
#  'tamarillo',
#  'tangerine',
#  'tomato',
#  'ugli fruit',
#  'watermelon']

# %%
for x in range(0, 100):
    
    random_dict = {}
    
    name_index = random.randint(0, len(names_sample) - 1)
    food_index = random.randint(0, len(food_sample) - 1)
    
    random_name = names_sample[name_index]
    random_food = food_sample[food_index]

    random_dict["login"] = "alien_test_" + str(x + 5)
    random_dict["password"] = "Password1"
    random_dict["name"] = random_name
    random_dict["age"] = x * 2 + 1
    random_dict["food"] = random_food
    random_dict["race"] = "Jaad" + str(x * 2 + 1)
    
    print(random_dict)
    
    requests.post("http://localhost:3000/api/v1/aliens/signup", data = random_dict)
# Out:
# {'login': 'alien_test_5', 'password': 'Password1', 'name': 'Abbate', 'age': 1, 'food': 'blueberry', 'race': 'Jaad1'}
# {'login': 'alien_test_6', 'password': 'Password1', 'name': 'Aaren', 'age': 3, 'food': 'breadfruit', 'race': 'Jaad3'}
# {'login': 'alien_test_7', 'password': 'Password1', 'name': 'Abbey', 'age': 5, 'food': 'passionfruit', 'race': 'Jaad5'}
# {'login': 'alien_test_8', 'password': 'Password1', 'name': 'Abbi', 'age': 7, 'food': 'lemon', 'race': 'Jaad7'}
# {'login': 'alien_test_9', 'password': 'Password1', 'name': 'Abbate', 'age': 9, 'food': 'pamelo', 'race': 'Jaad9'}
# {'login': 'alien_test_10', 'password': 'Password1', 'name': 'Abbot', 'age': 11, 'food': 'blackberry', 'race': 'Jaad11'}
# {'login': 'alien_test_11', 'password': 'Password1', 'name': 'Abagael', 'age': 13, 'food': 'rambutan', 'race': 'Jaad13'}
# {'login': 'alien_test_12', 'password': 'Password1', 'name': 'Aba', 'age': 15, 'food': 'blueberry', 'race': 'Jaad15'}
# {'login': 'alien_test_13', 'password': 'Password1', 'name': 'Abbey', 'age': 17, 'food': 'salal berry', 'race': 'Jaad17'}
# {'login': 'alien_test_14', 'password': 'Password1', 'name': 'Abad', 'age': 19, 'food': 'pamelo', 'race': 'Jaad19'}
# {'login': 'alien_test_15', 'password': 'Password1', 'name': 'Abagail', 'age': 21, 'food': 'cherry', 'race': 'Jaad21'}
# {'login': 'alien_test_16', 'password': 'Password1', 'name': 'Aarika', 'age': 23, 'food': 'nectarine', 'race': 'Jaad23'}
# {'login': 'alien_test_17', 'password': 'Password1', 'name': 'Aba', 'age': 25, 'food': 'satsuma', 'race': 'Jaad25'}
# {'login': 'alien_test_18', 'password': 'Password1', 'name': 'Abbate', 'age': 27, 'food': 'cranberry', 'race': 'Jaad27'}
# {'login': 'alien_test_19', 'password': 'Password1', 'name': 'Abad', 'age': 29, 'food': 'pear', 'race': 'Jaad29'}
# {'login': 'alien_test_20', 'password': 'Password1', 'name': 'Aaronson', 'age': 31, 'food': 'papaya', 'race': 'Jaad31'}
# {'login': 'alien_test_21', 'password': 'Password1', 'name': 'Aba', 'age': 33, 'food': 'ugli fruit', 'race': 'Jaad33'}
# {'login': 'alien_test_22', 'password': 'Password1', 'name': 'Ab', 'age': 35, 'food': 'pamelo', 'race': 'Jaad35'}
# {'login': 'alien_test_23', 'password': 'Password1', 'name': 'Ab', 'age': 37, 'food': 'quince', 'race': 'Jaad37'}
# {'login': 'alien_test_24', 'password': 'Password1', 'name': 'Abbot', 'age': 39, 'food': 'quince', 'race': 'Jaad39'}
# {'login': 'alien_test_25', 'password': 'Password1', 'name': 'Abagael', 'age': 41, 'food': 'pomelo', 'race': 'Jaad41'}
# {'login': 'alien_test_26', 'password': 'Password1', 'name': 'Aba', 'age': 43, 'food': 'raspberry', 'race': 'Jaad43'}
# {'login': 'alien_test_27', 'password': 'Password1', 'name': 'Ab', 'age': 45, 'food': 'bell pepper', 'race': 'Jaad45'}
# {'login': 'alien_test_28', 'password': 'Password1', 'name': 'Aalst', 'age': 47, 'food': 'breadfruit', 'race': 'Jaad47'}
# {'login': 'alien_test_29', 'password': 'Password1', 'name': 'Abbotsen', 'age': 49, 'food': 'elderberry', 'race': 'Jaad49'}
# {'login': 'alien_test_30', 'password': 'Password1', 'name': 'Abbot', 'age': 51, 'food': 'watermelon', 'race': 'Jaad51'}
# {'login': 'alien_test_31', 'password': 'Password1', 'name': 'Aara', 'age': 53, 'food': 'orange', 'race': 'Jaad53'}
# {'login': 'alien_test_32', 'password': 'Password1', 'name': 'Abbotsen', 'age': 55, 'food': 'redcurrant', 'race': 'Jaad55'}
# {'login': 'alien_test_33', 'password': 'Password1', 'name': 'Ab', 'age': 57, 'food': 'cherimoya', 'race': 'Jaad57'}
# {'login': 'alien_test_34', 'password': 'Password1', 'name': 'Aba', 'age': 59, 'food': 'raspberry', 'race': 'Jaad59'}
# {'login': 'alien_test_35', 'password': 'Password1', 'name': 'Abbotson', 'age': 61, 'food': 'purple mangosteen', 'race': 'Jaad61'}
# {'login': 'alien_test_36', 'password': 'Password1', 'name': 'Aaron', 'age': 63, 'food': 'blueberry', 'race': 'Jaad63'}
# {'login': 'alien_test_37', 'password': 'Password1', 'name': 'Abbie', 'age': 65, 'food': 'dragonfruit', 'race': 'Jaad65'}
# {'login': 'alien_test_38', 'password': 'Password1', 'name': 'Abbot', 'age': 67, 'food': 'jackfruit', 'race': 'Jaad67'}
# {'login': 'alien_test_39', 'password': 'Password1', 'name': 'Aaren', 'age': 69, 'food': 'nectarine', 'race': 'Jaad69'}
# {'login': 'alien_test_40', 'password': 'Password1', 'name': 'Abbate', 'age': 71, 'food': 'kiwi fruit', 'race': 'Jaad71'}
# {'login': 'alien_test_41', 'password': 'Password1', 'name': 'Aara', 'age': 73, 'food': 'tamarillo', 'race': 'Jaad73'}
# {'login': 'alien_test_42', 'password': 'Password1', 'name': 'Aarika', 'age': 75, 'food': 'jackfruit', 'race': 'Jaad75'}
# {'login': 'alien_test_43', 'password': 'Password1', 'name': 'Abad', 'age': 77, 'food': 'boysenberry', 'race': 'Jaad77'}
# {'login': 'alien_test_44', 'password': 'Password1', 'name': 'Abagael', 'age': 79, 'food': 'tangerine', 'race': 'Jaad79'}
# {'login': 'alien_test_45', 'password': 'Password1', 'name': 'Abbot', 'age': 81, 'food': 'goji berry', 'race': 'Jaad81'}
# {'login': 'alien_test_46', 'password': 'Password1', 'name': 'Abad', 'age': 83, 'food': 'blood orange', 'race': 'Jaad83'}
# {'login': 'alien_test_47', 'password': 'Password1', 'name': 'Aaron', 'age': 85, 'food': 'blackberry', 'race': 'Jaad85'}
# {'login': 'alien_test_48', 'password': 'Password1', 'name': 'Abbotsen', 'age': 87, 'food': 'orange', 'race': 'Jaad87'}
# {'login': 'alien_test_49', 'password': 'Password1', 'name': 'Abana', 'age': 89, 'food': 'cloudberry', 'race': 'Jaad89'}
# {'login': 'alien_test_50', 'password': 'Password1', 'name': 'Ab', 'age': 91, 'food': 'clementine', 'race': 'Jaad91'}
# {'login': 'alien_test_51', 'password': 'Password1', 'name': 'Abagael', 'age': 93, 'food': 'clementine', 'race': 'Jaad93'}
# {'login': 'alien_test_52', 'password': 'Password1', 'name': 'Abagail', 'age': 95, 'food': 'guava', 'race': 'Jaad95'}
# {'login': 'alien_test_53', 'password': 'Password1', 'name': 'Ab', 'age': 97, 'food': 'redcurrant', 'race': 'Jaad97'}
# {'login': 'alien_test_54', 'password': 'Password1', 'name': 'Abbotsen', 'age': 99, 'food': 'mandarine', 'race': 'Jaad99'}
# {'login': 'alien_test_55', 'password': 'Password1', 'name': 'Aara', 'age': 101, 'food': 'kumquat', 'race': 'Jaad101'}
# {'login': 'alien_test_56', 'password': 'Password1', 'name': 'Abbotson', 'age': 103, 'food': 'apricot', 'race': 'Jaad103'}
# {'login': 'alien_test_57', 'password': 'Password1', 'name': 'Abagael', 'age': 105, 'food': 'huckleberry', 'race': 'Jaad105'}
# {'login': 'alien_test_58', 'password': 'Password1', 'name': 'Abba', 'age': 107, 'food': 'physalis', 'race': 'Jaad107'}
# {'login': 'alien_test_59', 'password': 'Password1', 'name': 'Abbie', 'age': 109, 'food': 'physalis', 'race': 'Jaad109'}
# {'login': 'alien_test_60', 'password': 'Password1', 'name': 'Aarika', 'age': 111, 'food': 'elderberry', 'race': 'Jaad111'}
# {'login': 'alien_test_61', 'password': 'Password1', 'name': 'Abbotsen', 'age': 113, 'food': 'lemon', 'race': 'Jaad113'}
# {'login': 'alien_test_62', 'password': 'Password1', 'name': 'Abana', 'age': 115, 'food': 'loquat', 'race': 'Jaad115'}
# {'login': 'alien_test_63', 'password': 'Password1', 'name': 'Aaronson', 'age': 117, 'food': 'mandarine', 'race': 'Jaad117'}
# {'login': 'alien_test_64', 'password': 'Password1', 'name': 'Aarika', 'age': 119, 'food': 'cherry', 'race': 'Jaad119'}
# {'login': 'alien_test_65', 'password': 'Password1', 'name': 'Aarika', 'age': 121, 'food': 'kiwi fruit', 'race': 'Jaad121'}
# {'login': 'alien_test_66', 'password': 'Password1', 'name': 'Aaberg', 'age': 123, 'food': 'goji berry', 'race': 'Jaad123'}
# {'login': 'alien_test_67', 'password': 'Password1', 'name': 'Abagail', 'age': 125, 'food': 'jujube', 'race': 'Jaad125'}
# {'login': 'alien_test_68', 'password': 'Password1', 'name': 'Aaron', 'age': 127, 'food': 'dragonfruit', 'race': 'Jaad127'}
# {'login': 'alien_test_69', 'password': 'Password1', 'name': 'Abbie', 'age': 129, 'food': 'grape', 'race': 'Jaad129'}
# {'login': 'alien_test_70', 'password': 'Password1', 'name': 'Aba', 'age': 131, 'food': 'apricot', 'race': 'Jaad131'}
# {'login': 'alien_test_71', 'password': 'Password1', 'name': 'Aaberg', 'age': 133, 'food': 'blackberry', 'race': 'Jaad133'}
# {'login': 'alien_test_72', 'password': 'Password1', 'name': 'Abad', 'age': 135, 'food': 'apple', 'race': 'Jaad135'}
# {'login': 'alien_test_73', 'password': 'Password1', 'name': 'Abbi', 'age': 137, 'food': 'cantaloupe', 'race': 'Jaad137'}
# {'login': 'alien_test_74', 'password': 'Password1', 'name': 'Aalst', 'age': 139, 'food': 'lime', 'race': 'Jaad139'}
# {'login': 'alien_test_75', 'password': 'Password1', 'name': 'Aba', 'age': 141, 'food': 'purple mangosteen', 'race': 'Jaad141'}
# {'login': 'alien_test_76', 'password': 'Password1', 'name': 'Aara', 'age': 143, 'food': 'avocado', 'race': 'Jaad143'}
# {'login': 'alien_test_77', 'password': 'Password1', 'name': 'Aba', 'age': 145, 'food': 'lime', 'race': 'Jaad145'}
# {'login': 'alien_test_78', 'password': 'Password1', 'name': 'Abagael', 'age': 147, 'food': 'grape', 'race': 'Jaad147'}
# {'login': 'alien_test_79', 'password': 'Password1', 'name': 'Abbotsen', 'age': 149, 'food': 'nut', 'race': 'Jaad149'}
# {'login': 'alien_test_80', 'password': 'Password1', 'name': 'Aaronson', 'age': 151, 'food': 'purple mangosteen', 'race': 'Jaad151'}
# {'login': 'alien_test_81', 'password': 'Password1', 'name': 'Abbate', 'age': 153, 'food': 'tamarillo', 'race': 'Jaad153'}
# {'login': 'alien_test_82', 'password': 'Password1', 'name': 'Ab', 'age': 155, 'food': 'jambul', 'race': 'Jaad155'}
# {'login': 'alien_test_83', 'password': 'Password1', 'name': 'Aara', 'age': 157, 'food': 'jambul', 'race': 'Jaad157'}
# {'login': 'alien_test_84', 'password': 'Password1', 'name': 'Abbate', 'age': 159, 'food': 'blueberry', 'race': 'Jaad159'}
# {'login': 'alien_test_85', 'password': 'Password1', 'name': 'Abagael', 'age': 161, 'food': 'goji berry', 'race': 'Jaad161'}
# {'login': 'alien_test_86', 'password': 'Password1', 'name': 'Aalst', 'age': 163, 'food': 'banana', 'race': 'Jaad163'}
# {'login': 'alien_test_87', 'password': 'Password1', 'name': 'Abate', 'age': 165, 'food': 'goji berry', 'race': 'Jaad165'}
# {'login': 'alien_test_88', 'password': 'Password1', 'name': 'Abba', 'age': 167, 'food': 'lychee', 'race': 'Jaad167'}
# {'login': 'alien_test_89', 'password': 'Password1', 'name': 'Abate', 'age': 169, 'food': 'grapefruit', 'race': 'Jaad169'}
# {'login': 'alien_test_90', 'password': 'Password1', 'name': 'Aaronson', 'age': 171, 'food': 'cantaloupe', 'race': 'Jaad171'}
# {'login': 'alien_test_91', 'password': 'Password1', 'name': 'Abagael', 'age': 173, 'food': 'papaya', 'race': 'Jaad173'}
# {'login': 'alien_test_92', 'password': 'Password1', 'name': 'Aaronson', 'age': 175, 'food': 'blood orange', 'race': 'Jaad175'}
# {'login': 'alien_test_93', 'password': 'Password1', 'name': 'Abagael', 'age': 177, 'food': 'gooseberry', 'race': 'Jaad177'}
# {'login': 'alien_test_94', 'password': 'Password1', 'name': 'Ab', 'age': 179, 'food': 'loquat', 'race': 'Jaad179'}
# {'login': 'alien_test_95', 'password': 'Password1', 'name': 'Abbie', 'age': 181, 'food': 'passionfruit', 'race': 'Jaad181'}
# {'login': 'alien_test_96', 'password': 'Password1', 'name': 'Abbe', 'age': 183, 'food': 'kumquat', 'race': 'Jaad183'}
# {'login': 'alien_test_97', 'password': 'Password1', 'name': 'Aalst', 'age': 185, 'food': 'feijoa', 'race': 'Jaad185'}
# {'login': 'alien_test_98', 'password': 'Password1', 'name': 'Abagail', 'age': 187, 'food': 'rambutan', 'race': 'Jaad187'}
# {'login': 'alien_test_99', 'password': 'Password1', 'name': 'Abbey', 'age': 189, 'food': 'lime', 'race': 'Jaad189'}
# {'login': 'alien_test_100', 'password': 'Password1', 'name': 'Abba', 'age': 191, 'food': 'satsuma', 'race': 'Jaad191'}
# {'login': 'alien_test_101', 'password': 'Password1', 'name': 'Abbot', 'age': 193, 'food': 'bell pepper', 'race': 'Jaad193'}
# {'login': 'alien_test_102', 'password': 'Password1', 'name': 'Abbot', 'age': 195, 'food': 'feijoa', 'race': 'Jaad195'}
# {'login': 'alien_test_103', 'password': 'Password1', 'name': 'Aaberg', 'age': 197, 'food': 'grape', 'race': 'Jaad197'}
# {'login': 'alien_test_104', 'password': 'Password1', 'name': 'Abbate', 'age': 199, 'food': 'cucumber', 'race': 'Jaad199'}
